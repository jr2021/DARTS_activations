# %%
# %run -i 'RNNResNet8.py'
# Out:
# WARNING [07/19 01:00:07 nl.search_spaces.core.graph]: Update function could not be veryfied. Be cautious with the setting of `private_edge_data` in `update_edges()`
# WARNING [07/19 01:00:07 nl.search_spaces.core.graph]: Update function could not be veryfied. Be cautious with the setting of `private_edge_data` in `update_edges()`
# WARNING [07/19 01:00:07 nl.search_spaces.core.graph]: Update function could not be veryfied. Be cautious with the setting of `private_edge_data` in `update_edges()`
# WARNING [07/19 01:00:07 nl.search_spaces.core.graph]: Update function could not be veryfied. Be cautious with the setting of `private_edge_data` in `update_edges()`
# WARNING [07/19 01:00:07 nl.search_spaces.core.graph]: Update function could not be veryfied. Be cautious with the setting of `private_edge_data` in `update_edges()`
# [07/19 01:00:07 nl.optimizers.oneshot.darts.optimizer]: Parsed graph:
# Graph activation_1:
#  Graph(
#   (activation_1-edge(1,2)): MixedOp(
# ...
